# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dbName="X_train.csv"
df=pd.read_csv(dbName)

# %%
df.StudentID.count()
# Out:
# 678

# %%
df["sex"][df["sex"]=="F"].count()
# Out:
# 394

# %%
np.unique(df[df["age"]<=17].Mjob)
# Out:
# array(['at_home', 'health', 'other', 'services', 'teacher'], dtype=object)

# %%
df.iloc[:,19:]
# Out:
#     activities nursery higher internet romantic  famrel  freetime  goout  \
# 0           no     yes    yes      yes       no       4         3      3
# 1          yes     yes    yes      yes      yes       4         4      3
# 2          yes     yes    yes       no       no       2         4      4
# 3          yes     yes    yes      yes       no       5         3      3
# 4           no     yes     no      yes      yes       4         5      4
# ..         ...     ...    ...      ...      ...     ...       ...    ...
# 673        yes      no    yes      yes       no       5         3      3
# 674        yes     yes    yes      yes      yes       1         3      5
# 675         no     yes    yes      yes       no       4         1      1
# 676        yes      no    yes      yes      yes       4         5      5
# 677        yes      no    yes      yes       no       5         2      2
#
#      Dalc  Walc  health  absences  G1  G2
# 0       1     1       3         0  14  13
# ...
